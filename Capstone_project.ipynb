# %% [markdown]
# <a href="https://colab.research.google.com/github/mylarjeevan/C-CPP-Programming/blob/main/Capstone_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_sheet.csv")
X=df[['Hours']]
Y=df['Score']
model=LinearRegression()
model.fit(X,Y)
prediction=model.predict(X)
print(prediction)
mae=mean_absolute_error(Y,prediction)
mse=mean_squared_error(Y,prediction)
new_prediction=model.predict([[7]])

print("MAE:",mae)
print("MSE:",mse)
print(new_prediction)
# Out:
# [31.         35.33333333 39.66666667 44.         48.33333333 52.66666667
#  57.         61.33333333 65.66666667 70.        ]
# MAE: 0.8666666666666665
# MSE: 1.5333333333333337
# [57.]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
